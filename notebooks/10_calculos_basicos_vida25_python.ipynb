#  4.23336e-01 4.49171e-01 4.75035e-01 5.00918e-01 5.26808e-01 5.83877e-01
#  6.18746e-01 6.54849e-01 6.92209e-01 7.30838e-01 7.70736e-01 8.11884e-01
#  8.54241e-01 8.97733e-01 9.42245e-01 9.87609e-01 1.00000e+00]
# Longitud: 113

# %%
# Calculemos los lx, los metemos en un vector (tenemos en cuenta el desfase)
L = np.zeros(113)
L[0] = 1000000 * (1 - pasem1[0])

# %%
for i in range(1, 113):
    L[i] = L[i-1] * (1 - pasem1[i])

# %%
print("\nVector lx:")
print(L)
# Out:
# Vector lx:
# [9.94193000e+05 9.93777427e+05 9.93430599e+05 9.93145484e+05
#  9.92911102e+05 9.92712520e+05 9.92536810e+05 9.92373041e+05
#  9.92215254e+05 9.92057492e+05 9.91889834e+05 9.91700383e+05
#  9.91470308e+05 9.91178816e+05 9.90803159e+05 9.90321629e+05
#  9.89723475e+05 9.89010874e+05 9.88299775e+05 9.87576340e+05
#  9.86837633e+05 9.86082702e+05 9.85308627e+05 9.84517424e+05
#  9.83711104e+05 9.82894624e+05 9.82077839e+05 9.81269589e+05
#  9.80477704e+05 9.79708029e+05 9.78956593e+05 9.78217481e+05
#  9.77478927e+05 9.76722358e+05 9.75923399e+05 9.75056779e+05
#  9.74107074e+05 9.73064779e+05 9.71926293e+05 9.70688059e+05
#  9.69339773e+05 9.67856684e+05 9.66201649e+05 9.64339778e+05
#  9.62244268e+05 9.59897354e+05 9.57279714e+05 9.54361925e+05
#  9.51123775e+05 9.47534234e+05 9.43566908e+05 9.39194419e+05
#  9.34412041e+05 9.29205497e+05 9.23542919e+05 9.17377347e+05
#  9.10680492e+05 9.03432386e+05 8.95661061e+05 8.87409335e+05
#  8.78718936e+05 8.69624195e+05 8.60152248e+05 8.50302645e+05
#  8.40055647e+05 8.29384420e+05 8.17724105e+05 8.04915275e+05
#  7.90779352e+05 7.75116386e+05 7.57707272e+05 7.38306177e+05
#  7.16633938e+05 6.92388062e+05 6.65245065e+05 6.34885276e+05
#  6.01017321e+05 5.63420682e+05 5.21991233e+05 4.76814457e+05
#  4.30652143e+05 3.84064624e+05 3.37712633e+05 2.92318314e+05
#  2.48621403e+05 2.07338068e+05 1.69147432e+05 1.34654042e+05
#  1.04336685e+05 7.84920705e+04 5.71926192e+04 4.02737270e+04
#  2.73517406e+04 1.78814192e+04 1.12324817e+04 6.76700861e+03
#  3.90229025e+03 2.14949464e+03 1.12840945e+03 5.63168847e+02
#  2.66486993e+02 1.10891367e+02 4.22777772e+01 1.45922171e+01
#  4.49135309e+00 1.20890158e+00 2.77157612e-01 5.21377813e-02
#  7.59955086e-03 7.77183268e-04 4.48862197e-05 5.56185148e-07
#  0.00000000e+00]

# %%
# Gráficos
plt.figure(figsize=(12, 5))
plt.plot(L)
plt.title('Supervivientes lx')
plt.xlabel('Edad')
plt.ylabel('Número de supervivientes')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.plot(pasem1)
plt.title('Probabilidades de muerte qx')
plt.xlabel('Edad')
plt.ylabel('qx')
plt.grid(True)
plt.show()

# %%
# Probabilidades básicas
def px(x):
    """Probabilidad de supervivencia de x a x+1"""
    return L[x+1] / L[x]

# %%
print(f"\npx(20) = {px(20)}")
# Out:
# px(20) = 0.999235

# %%
def qx(x):
    """Probabilidad de muerte entre x y x+1"""
    return 1 - (L[x+1] / L[x])

# %%
print(f"qx(20) = {qx(20)}")
# Out:
# qx(20) = 0.0007650000000000157

# %%
def tpx(x, t):
    """Probabilidad de que una persona de edad x sobreviva t años"""
    return L[x+t] / L[x]

# %%
print(f"\ntpx(20,10) = {tpx(20, 10)}")
print(f"tpx(50,40) = {tpx(50, 40)}")
# Out:
# tpx(20,10) = 0.9920138436440877
# tpx(50,40) = 0.060613210072015054

# %%
def tqx(x, t):
    """Probabilidad de que una persona de edad x muera dentro de t años"""
    return 1 - (L[x+t] / L[x])

# %%
print(f"\ntqx(20,10) = {tqx(20, 10)}")
# Out:
# tqx(20,10) = 0.007986156355912266

# %%
def kqx(x, t):
    """Probabilidad de que una persona de edad x muera entre los años t y t+1"""
    return (L[x+t] - L[x+t+1]) / L[x]

# %%
print(f"kqx(20,10) = {kqx(20, 10)}")
# Out:
# kqx(20,10) = 0.0007489704519512816

# %%
# Factor de actualización actuarial
def tEX(x, n, i):
    """Factor de actualización actuarial"""
    return (1 + i)**(-n) * L[x+n] / L[x]

# %%
print(f"\ntEX(20,50,0.03) = {tEX(20, 50, 0.03)}")
# Out:
# tEX(20,50,0.03) = 0.17514369881970723

# %%
# Valor actual actuarial del seguro vida entera
def Ax(x, i):
    """Valor actual actuarial del seguro de vida entera"""
    t = np.arange(0, 113-x-1)
    return np.sum((1+i)**(-t-1) * ((L[x+t] - L[x+t+1]) / L[x]))

# %%
print(f"\nAx(30,0.02) = {Ax(30, 0.02)}")
# Out:
# Ax(30,0.02) = 0.40735868756359855

# %%
# Valor actual actuarial del seguro temporal
def Axn(x, n, i):
    """Valor actual actuarial del seguro temporal a n años"""
    t = np.arange(0, n)
    return np.sum((1+i)**(-t-1) * ((L[x+t] - L[x+t+1]) / L[x]))

# %%
print(f"Axn(30,10,0.02) = {Axn(30, 10, 0.02)}")
# Out:
# Axn(30,10,0.02) = 0.0087184726739101

# %%
# Renta vitalicia prepagable
def ax(x, i):
    """Valor actual actuarial de renta vitalicia prepagable"""
    t = np.arange(0, 113-x-1)
    return np.sum((1+i)**(-t) * (L[x+t] / L[x]))

# %%
print(f"\nax(40,0.03) = {ax(40, 0.03)}")
print(f"ax(40,0.02) = {ax(40, 0.02)}")
# Out:
# ax(40,0.03) = 22.233451829923116
# ax(40,0.02) = 25.971178289124325

# %%
# Renta temporal prepagable
def axn(x, n, i):
    """Valor actual actuarial de renta temporal prepagable a n años"""
    t = np.arange(0, n)
    return np.sum((1+i)**(-t) * (L[x+t] / L[x]))

# %%
print(f"\naxn(40,10,0.03) = {axn(40, 10, 0.03)}")
# Out:
# axn(40,10,0.03) = 8.706886506644594

# %%
# Renta diferida nax = prima única
def nax(x, n, i):
    """Valor actual actuarial de renta vitalicia diferida n años"""
    return tEX(x, n, i) * ax(x+n, i)

# %%
print(f"\nnax(20,10,0.03) = {nax(20, 10, 0.03)}")
print(f"nax(20,10,0.02) = {nax(20, 10, 0.02)}")
print(f"nax(20,45,0.03) = {nax(20, 45, 0.03)}")
print(f"nax(20,45,0.02) = {nax(20, 45, 0.02)}")
# Out:
# nax(20,10,0.03) = 18.553989483705084
# nax(20,10,0.02) = 24.596771902365887
# nax(20,45,0.03) = 2.721395012718159
# nax(20,45,0.02) = 4.556452072694197

# %%
# Renta vitalicia variable en progresión geométrica
def qax(x, i, q):
    """Valor actual actuarial de renta vitalicia variable en progresión geométrica"""
    t = np.arange(0, 113-x-1)
    return np.sum((q**t) * (1+i)**(-t) * (L[x+t] / L[x]))

# %%
print(f"\nqax(40,0.03,1) = {qax(40, 0.03, 1)}")
# Out:
# qax(40,0.03,1) = 22.233451829923116

# %%
# Renta temporal variable en progresión geométrica
def qaxn(x, n, i, q):
    """Valor actual actuarial de renta temporal variable en progresión geométrica"""
    t = np.arange(0, n)
    return np.sum((q**t) * (1+i)**(-t) * (L[x+t] / L[x]))

# %%
print(f"\nqaxn(40,10,0.03,1) = {qaxn(40, 10, 0.03, 1)}")
print(f"qaxn(40,10,0.03,1.05) = {qaxn(40, 10, 0.03, 1.05)}")
# Out:
# qaxn(40,10,0.03,1) = 8.706886506644594
# qaxn(40,10,0.03,1.05) = 10.811281723694796

# %%
# Prima vitalicia seguro vida entera
def Primavitalicia(x, i):
    """Prima vitalicia para seguro de vida entera"""
    return Ax(x, i) / ax(x, i)

# %%
print(f"\nPrimavitalicia(40,0.05) = {Primavitalicia(40, 0.05)}")
# Out:
# Primavitalicia(40,0.05) = 0.011288351022246602

# %%
# Número de años completos de vida hasta la muerte
# Cabeza de 30 años
# Probabilidades
t = np.arange(0, 113-30-1)
s = np.array([kqx(30, ti) for ti in t])

# %%
print(f"\nDistribución de años completos de vida (edad 30):")
print(s)
# Out:
# Distribución de años completos de vida (edad 30):
# [7.55000000e-04 7.54429975e-04 7.72831701e-04 8.16133110e-04
#  8.85248625e-04 9.70119931e-04 1.06469947e-03 1.16295840e-03
#  1.26485087e-03 1.37726813e-03 1.51496998e-03 1.69061115e-03
#  1.90189288e-03 2.14055491e-03 2.39736244e-03 2.67390822e-03
#  2.98050862e-03 3.30775648e-03 3.66670101e-03 4.05260649e-03
#  4.46647899e-03 4.88517879e-03 5.31846246e-03 5.78429967e-03
#  6.29810614e-03 6.84080855e-03 7.40390952e-03 7.93837586e-03
#  8.42910238e-03 8.87720629e-03 9.29023927e-03 9.67555334e-03
#  1.00613280e-02 1.04672641e-02 1.09006129e-02 1.19109628e-02
#  1.30841658e-02 1.44397843e-02 1.59996539e-02 1.77833360e-02
#  1.98181358e-02 2.21381006e-02 2.47670593e-02 2.77264559e-02
#  3.10123955e-02 3.45959722e-02 3.84048065e-02 4.23200067e-02
#  4.61478839e-02 4.71546085e-02 4.75889518e-02 4.73483622e-02
#  4.63701040e-02 4.46362088e-02 4.21707517e-02 3.90115718e-02
#  3.52348515e-02 3.09690520e-02 2.64001635e-02 2.17572990e-02
#  1.72825765e-02 1.31997542e-02 9.67389305e-03 6.79186143e-03
#  4.56146181e-03 2.92629763e-03 1.79047327e-03 1.04303418e-03
#  5.77390878e-04 3.03059253e-04 1.58940271e-04 7.00884904e-05
#  2.82806820e-05 1.03179896e-05 3.35301027e-06 9.51772504e-07
#  2.29856801e-07 4.54956131e-08 6.96901951e-09 7.48038323e-10
#  4.52829419e-11 5.68140765e-13]

# %%
# Gráficas de la cuantía
plt.figure(figsize=(10, 6))
plt.plot(s)
plt.title('Probabilidad de muerte en el año t (edad inicial 30)')
plt.xlabel('Años desde edad 30')
plt.ylabel('Probabilidad kqx(30,t)')
plt.grid(True)
plt.show()

# %%
# Verificar que suman 1
suma_probabilidades = np.sum([kqx(30, ti) for ti in range(0, 113-30-1)])
print(f"\nSuma de probabilidades: {suma_probabilidades} (debe ser ≈ 1)")
# Out:
# Suma de probabilidades: 0.9999999999999999 (debe ser ≈ 1)
